# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# adc.json  gdrive  sample_data

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
# !ls
# Out:
# 'My Drive'  'Shared drives'

# %%
cd My Drive
# Out:
# /content/gdrive/My Drive

# %%
# !ls
# Out:
# 'Class Information.pdf'
#  colab_jk
# 'Colab Notebooks'
# 'Computer Science'
# 'english mp3'
#  Film
# 'Flexcil backup 2019-03-17 22.43.10.flex'
#  foo.txt
# 'Harrington, Verbal Advantage; 10 Easy Steps to a Powerful Vocabulary.pdf'
# 'Harrington, Verbal Advantage Success Edition.pdf'
# 'ì'$'\302\232''°ì'$'\302\210\302\230''ê³¼í'$'\302\225\302\231''ë'$'\302\217\302\204''ì'$'\302\204\302\234'' (1).pdf'
# 'ì'$'\302\232''°ì'$'\302\210\302\230''ê³¼í'$'\302\225\302\231''ë'$'\302\217\302\204''ì'$'\302\204\302\234''.pdf'
#  jin.txt
#  jk001
#  jk002
#  jk003
#  Journal
# 'My pdf'
# '##my words##'
# 'new doc 2019-03-02 16.03.34_20190302172722.pdf'
#  무제.pdf
# '제이미 블로그 컴퓨터 전공 이야기.pdf'
# '아이패드에서 토렌트 실행.pdf'
# 'pdf for kids'
# 'Private lesson'
#  project
# 'Python 기초'
# 'Safari - 14 Apr 2019 at 11:51 AM.pdf'
# 'Safari - 14 Apr 2019 at 12:36 AM.pdf'
# 'Safari - 18 Apr 2019 at 9:39 AM.pdf'
# 'Safari - 2019. 5. 25. 오후 9:43.pdf'
# 'Safari - 2019. 7. 11. 오전 1:36.pdf'
# 'Safari - 21 Apr 2019 at 10:17 AM (1).pdf'
# 'Safari - 21 Apr 2019 at 10:17 AM.pdf'
# 'Safari - 24 Apr 2019 at 11:41 PM.pdf'
# 'Safari - 2 Apr 2019 at 12:07 AM.pdf'
# 'Safari - 31 Mar 2019 at 12:18 PM.pdf'
# 'Safari - 31 Mar 2019 at 2:43 AM.pdf'
# 'Safari - 4 Apr 2019 at 11:41 PM.pdf'
# 'Safari - 7 Apr 2019 at 10:20 PM.pdf'
# 'Safari - 7 Apr 2019 at 3:00 PM.pdf'
# 'Safari - 8 Apr 2019 at 12:10 PM.pdf'
#  Snulife
#  test_colab
#  Toefl
#  URL
#  Utility
# 'Verb. Adv. mp3'
# '요양원(수입지출).xlsx'

# %%
# !ls -itr
# Out:
# 16  Toefl
# 17  Film
# 18  Utility
# 19  Journal
# 20 'pdf for kids'
# 21 'new doc 2019-03-02 16.03.34_20190302172722.pdf'
# 22 'Private lesson'
# 23 'Class Information.pdf'
# 24 'My pdf'
# 25 'Flexcil backup 2019-03-17 22.43.10.flex'
# 26 'english mp3'
# 27  Snulife
# 28 'Safari - 31 Mar 2019 at 2:43 AM.pdf'
# 29 'Safari - 31 Mar 2019 at 12:18 PM.pdf'
# 30  무제.pdf
# 31 'Safari - 2 Apr 2019 at 12:07 AM.pdf'
# 32 'Harrington, Verbal Advantage Success Edition.pdf'
# 33 'Harrington, Verbal Advantage; 10 Easy Steps to a Powerful Vocabulary.pdf'
# 34  URL
# 35 'Verb. Adv. mp3'
# 36 'Safari - 4 Apr 2019 at 11:41 PM.pdf'
# 37 'Safari - 7 Apr 2019 at 3:00 PM.pdf'
# 38 'Safari - 7 Apr 2019 at 10:20 PM.pdf'
# 39 '##my words##'
# 40 'Safari - 8 Apr 2019 at 12:10 PM.pdf'
# 41 'Safari - 14 Apr 2019 at 12:36 AM.pdf'
# 42 'ì'$'\302\232''°ì'$'\302\210\302\230''ê³¼í'$'\302\225\302\231''ë'$'\302\217\302\204''ì'$'\302\204\302\234'' (1).pdf'
# 43 'Safari - 14 Apr 2019 at 11:51 AM.pdf'
# 44 'Safari - 18 Apr 2019 at 9:39 AM.pdf'
# 45 'Safari - 21 Apr 2019 at 10:17 AM.pdf'
# 46 'Safari - 21 Apr 2019 at 10:17 AM (1).pdf'
# 47 'Safari - 24 Apr 2019 at 11:41 PM.pdf'
# 48 'ì'$'\302\232''°ì'$'\302\210\302\230''ê³¼í'$'\302\225\302\231''ë'$'\302\217\302\204''ì'$'\302\204\302\234''.pdf'
# 49 'Safari - 2019. 5. 25. 오후 9:43.pdf'
# 50 '요양원(수입지출).xlsx'
# 51 '아이패드에서 토렌트 실행.pdf'
# 52 '제이미 블로그 컴퓨터 전공 이야기.pdf'
# 53 'Python 기초'
# 54 'Safari - 2019. 7. 11. 오전 1:36.pdf'
# 55 'Computer Science'
# 56  colab_jk
# 57 'Colab Notebooks'
# 58  test_colab
# 59  jk001
# 60  jk002
# 61  jk003
# 62  foo.txt
# 63  jin.txt
# 64  project

# %%
cd
# Out:
# /root

# %%
# !ls

# %%
# !dir

# %%
cd root
# Out:
# [Errno 2] No such file or directory: 'root'
# /root

# %%
cd computer
# Out:
# [Errno 2] No such file or directory: 'computer'
# /root
